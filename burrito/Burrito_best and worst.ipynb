# %% [markdown]
# # San Diego Burrito Analytics: Best and worst burritos

# %% [markdown]
# ### Default imports

# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

import seaborn as sns
sns.set_style("white")

# %% [markdown]
# ### Load data

# %%
import util
df = util.load_burritos()
N = df.shape[0]
df.head()
# Out:
#                Location      Burrito       Date Neighborhood  \
# 0    donato's taco shop  California   1/18/2016      Miramar
# 1  oscar's mexican food  California   1/24/2016   San Marcos
# 2  oscar's mexican food     Carnitas  1/24/2016         None
# 3  oscar's mexican food  Carne asada  1/24/2016         None
# 4          pollos maria   California  1/27/2016     Carlsbad
#
#                     Address  \
# 0           6780 Miramar Rd
# 1  225 S Rancho Santa Fe Rd
# 2                      None
# 3                      None
# 4           3055 Harding St
#
#                                                  URL  Yelp  Google Chips  \
# 0                        http://donatostacoshop.net/   3.5     4.2  None
# 1  http://www.yelp.com/biz/oscars-mexican-food-sa...   3.5     3.3  None
# 2                                               None   NaN     NaN  None
# 3                                               None   NaN     NaN  None
# ...

# %% [markdown]
# ### Worst burritos

# %%
df.loc[33]
# Out:
# Location                 raul's mexican food
# Burrito                          carne asada
# Date                               3/11/2016
# Neighborhood                            None
# Address                                 None
# URL                                     None
# Yelp                                     NaN
# Google                                   NaN
# Chips                                   None
# Cost                                       5
# Hunger                                     1
# Mass (g)                                 NaN
# Length                                   NaN
# Circum                                   NaN
# Volume                                   NaN
# Tortilla                                   2
# Temp                                     NaN
# Meat                                       1
# Fillings                                   1
# Meat:filling                             0.5
# Uniformity                                 1
# ...

# %%
df.sort_values('overall')[['Location','Burrito','overall']]
# Out:
#                         Location                     Burrito  overall
# 33           raul's mexican food                 carne asada      1.0
# 101  roberto's very mexican food               Chicken asada      1.5
# 71                senor grubby's                  California      1.5
# 187       lucha libre north park                   Holy Moly      1.5
# 97                       goody's                      Custom      1.8
# 72                senor grubby's                      Pastor      1.8
# 146      los primos mexican food                 Carne asada      2.0
# 32           raul's mexican food            Chile verde pork      2.0
# 178       lucha libre north park             Bean and cheese      2.0
# 116      los primos mexican food                    Carnitas      2.0
# 275             lupe's taco shop           Spicy a la Diabla      2.0
# 263           gloria's taco shop                      Cabeza      2.0
# ...
