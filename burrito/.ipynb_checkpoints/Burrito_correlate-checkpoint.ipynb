# %% [markdown]
# # San Diego Burrito Analytics
#
# Scott Cole
#
# 23 April 2016
#
# This notebook contains analyses on the burrito ratings in San Diego, including:
# * How each metric correlates with one another.
# * Linear model of how each dimension contributes to the overall rating

# %% [markdown]
# # Default imports

# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

import seaborn as sns
sns.set_style("white")

# %% [markdown]
# # Load data

# %%
filename="burrito_current.csv"
df = pd.read_csv(filename)
N = df.shape[0]

# %% [markdown]
# # Metric correlations

# %%
dfcorr = df.corr()

# %%
from tools.misc import pearsonp
metricscorr = ['Hunger','Cost','Volume','Tortilla','Temp','Meat','Fillings','Meat:filling',
               'Uniformity','Salsa','Synergy','Wrap','overall']
M = len(metricscorr)

Mcorrmat = np.zeros((M,M))
Mpmat = np.zeros((M,M))
for m1 in range(M):
    for m2 in range(M):
        if m1 != m2:
            Mcorrmat[m1,m2] = dfcorr[metricscorr[m1]][metricscorr[m2]]
            Mpmat[m1,m2] = pearsonp(Mcorrmat[m1,m2],N)

# %%
from matplotlib import cm

clim1 = (-1,1)
plt.figure(figsize=(10,10))
cax = plt.pcolor(range(M+1), range(M+1), Mcorrmat, cmap=cm.bwr)
cbar = plt.colorbar(cax, ticks=(-1,-.5,0,.5,1))
cbar.ax.set_ylabel('Pearson correlation (r)', size=30)
plt.clim(clim1)
cbar.ax.set_yticklabels((-1,-.5,0,.5,1),size=20)
#plt.axis([2, M+1, floall[0],floall[-1]+10])
ax = plt.gca()
ax.set_yticks(np.arange(M)+.5)
ax.set_yticklabels(metricscorr,size=25)
ax.set_xticks(np.arange(M)+.5)
ax.set_xticklabels(metricscorr,size=9)
plt.tight_layout()

figname = 'metriccorrmat'
plt.savefig('C:/Users/Scott/Google Drive/qwm/burritos/figs/'+figname + '.png')

# %%
print Mpmat[0]
print Mcorrmat[0]
# Out:
# [ 0.          0.45348925  0.53282813  0.07853979  0.06722514  0.16986305
#   0.01787126  0.16977231  0.20838913  0.25156287  0.04443971  0.88706049
#   0.04126796]
# [ 0.          0.07580618  0.0631006   0.17675651  0.18376506  0.13834269
#   0.23643188  0.13837182  0.12688684  0.11572541  0.20145903 -0.01438256
#   0.20449178]

# %% [markdown]
# # Negative correlation: Cost and volume

# %%
plt.figure(figsize=(6,6))
ax = plt.gca()
df.plot(kind='scatter',x='Cost',y='Volume',ax=ax,**{'s':40,'color':'k'})
plt.xlabel('Cost ($)',size=20)
plt.ylabel('Volume (L)',size=20)
plt.xticks(np.arange(5,11),size=15)
plt.yticks(np.arange(.6,1.2,.1),size=15)
print df.corr()['Cost']['Volume']
from tools.misc import pearsonp
print pearsonp(df.corr()['Cost']['Volume'],len(df[['Cost','Volume']].dropna()))
# Out:
# -0.615137527711
# 0.00106579619198

# %%
# Visualize some correlations

from tools.plt import scatt_corr
scatt_corr(df['overall'].values,df['Meat'].values,
          xlabel = 'overall rating', ylabel='meat rating', xlim = (-.5,5.5),ylim = (-.5,5.5),xticks=range(6),yticks=range(6))
          #showline = True)
    
scatt_corr(df['overall'].values,df['Wrap'].values,
          xlabel = 'overall rating', ylabel='wrap integrity rating', xlim = (-.5,5.5),ylim = (-.5,5.5),xticks=range(6),yticks=range(6))
          #showline = True)

# %% [markdown]
# # Linear regression
# Tutorial: https://github.com/justmarkham/DAT4/blob/master/notebooks/08_linear_regression.ipynb

# %%
# Categorical
catmet = ['Chips','Pico']
for m in catmet:
    df[m] = df[m].map({'x':1,'X':1})
    df[m] = df[m].fillna(0)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
dffull = df[['Tortilla','Fillings','Meat','overall','Chips','Pico']].dropna()
X = dffull[['Tortilla','Fillings','Meat','Chips','Pico']]
y = dffull['overall']
lm.fit(X,y)

print lm.intercept_
print lm.coef_

print 'R2 = ' + np.str(lm.score(X,y))
# Out:
# 0.324795622785
# [ 0.21100539  0.35819597  0.37247482 -0.06242908 -0.02808276]
# R2 = 0.720959946142

# %% [markdown]
# # Linear regression: ingredients

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# Get all ingredient keys
startingredients = 28
ingredientkeys = df.keys()[startingredients:]
# Get all ingredient keys with at least 10 burritos
Nlim = 10
ingredientkeys = ingredientkeys[df.count()[startingredients:].values>=Nlim]
# Make a dataframe for all ingredient keys
dfing = df[ingredientkeys]

# For each key, make binary
for k in dfing.keys():
    dfing[k] = dfing[k].map({'x':1,'X':1,1:1})
    dfing[k] = dfing[k].fillna(0)
# Out:
# C:\Users\Scott\Anaconda2\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Scott\Anaconda2\lib\site-packages\ipykernel\__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Add constant term
try:
    dfing['c']
except ValueError:
    dfing['c'] = np.ones(dfing.shape[0])
X = dfing
y = df['overall']
lm.fit(X,y)
print lm.intercept_
print lm.coef_

print 'R2 = ' + np.str(lm.score(X,y))
origR2 = lm.score(X,y)
# Out:
# 3.54514476096
# [ 0.0075616  -0.04413955 -0.08585657  0.20133069 -0.09287313  0.39069524
#  -0.0419008  -0.144794   -0.42256648  0.02135682  0.        ]
# R2 = 0.126702292076

# %%
Nsurr = 1000
randr2 = np.zeros(Nsurr)
for n in range(Nsurr):
    Xrand = np.random.rand(X.shape[0],X.shape[1])
    Xrand[:,0] = np.ones(dfing.shape[0])
    lm.fit(Xrand,y)
    randr2[n] = lm.score(Xrand,y)
print 'p = ' , np.mean(randr2>origR2)
# Out:
# p =  0.254

# %%
# Is this a null result? let's do t-tests
for k in dfing.keys():
    withk = df.overall[dfing[k].values==1].values
    nok = df.overall[dfing[k].values==0].values
    print k
    print sp.stats.ttest_ind(withk,nok)
# Out:
# Beef
# Ttest_indResult(statistic=1.0308680769541867, pvalue=0.30514014234813563)
# Pico
# Ttest_indResult(statistic=-0.28482149350358149, pvalue=0.77638192603357026)
# Guac
# Ttest_indResult(statistic=0.16910068559815722, pvalue=0.86606599315975141)
# Cheese
# Ttest_indResult(statistic=2.2895360282693358, pvalue=0.024193423289653692)
# Fries
# Ttest_indResult(statistic=1.9246425077026665, pvalue=0.05717435007006641)
# Sour cream
# Ttest_indResult(statistic=2.6715537786487733, pvalue=0.0088422382067924708)
# Pork
# Ttest_indResult(statistic=-1.2805565633781024, pvalue=0.203371965929078)
# Rice
# Ttest_indResult(statistic=-1.2606372818576765, pvalue=0.21043274246959154)
# Beans
# Ttest_indResult(statistic=-2.177647165199375, pvalue=0.031832207885684062)
# Sauce
# Ttest_indResult(statistic=-0.3079626634133712, pvalue=0.75876433303687207)

# %% [markdown]
# # Taco Stand case study: Meat-fillings correlation

# %%
plt.figure(figsize=(6,6))
ax = plt.gca()
df.plot(kind='scatter',x='Meat',y='Fillings',ax=ax,**{'s':40,'color':'k','alpha':.1})
plt.xlabel('Meat rating',size=20)
plt.ylabel('Non-meat rating',size=20)
plt.xticks(np.arange(0,6),size=15)
plt.yticks(np.arange(0,6),size=15)
print df.corr()['Meat']['Fillings']
from tools.misc import pearsonp
print pearsonp(df.corr()['Meat']['Fillings'],len(df[['Meat','Fillings']].dropna()))
# Out:
# 0.617311312364
# 1.29099956909e-11

# %%
# How many burritos at taco stand?
restrictCali = False
import re
reTS = re.compile('.*taco stand.*', re.IGNORECASE)
reCali = re.compile('.*cali.*', re.IGNORECASE)
locTS = np.ones(len(df))
for i in range(len(df)):
    mat = reTS.match(df['Location'][i])
    if mat is None:
        locTS[i] = 0
    else:
        if restrictCali:
            mat = reCali.match(df['Burrito'][i])
            if mat is None:
                locTS[i] = 0
print sum(locTS)
temp = np.arange(len(df))
dfTS = df.loc[temp[locTS==1]]
# Out:
# 16.0

# %%
plt.figure(figsize=(6,6))
ax = plt.gca()
dfTS.plot(kind='scatter',x='Meat',y='Fillings',ax=ax,**{'s':40,'color':'k','alpha':.1})
plt.xlabel('Meat rating',size=20)
plt.ylabel('Non-meat rating',size=20)
plt.xticks(np.arange(0,6),size=15)
plt.yticks(np.arange(0,6),size=15)
print dfTS.corr()['Meat']['Fillings']
from tools.misc import pearsonp
print pearsonp(dfTS.corr()['Meat']['Fillings'],len(dfTS[['Meat','Fillings']].dropna()))
# Out:
# 0.753794967197
# 0.000744707419522

# %% [markdown]
# # Hunger level relation to each metric

# %%
plt.figure(figsize=(6,6))
ax = plt.gca()
df.plot(kind='scatter',x='Hunger',y='overall',ax=ax,**{'s':40,'color':'k'})
plt.xlabel('Hunger',size=20)
plt.ylabel('Overall rating',size=20)
plt.xticks(np.arange(0,6),size=15)
plt.yticks(np.arange(0,6),size=15)
print df.corr()['Hunger']['overall']
from tools.misc import pearsonp
print pearsonp(df.corr()['Hunger']['overall'],len(df[['Hunger','overall']].dropna()))
# Out:
# 0.204491777509
# 0.0412679567415

# %% [markdown]
# # Model overall as a function of each main dimension

# %%
# indices correspond to: ['Hunger','Cost','Volume',Tortilla','Temp','Meat','Fillings','Meat:filling','Uniformity','Salsa','Synergy','Wrap']
print Mpmat[-1]
print Mcorrmat[-1]
# Out:
# [  4.12679567e-02   2.62088204e-01   3.76849619e-01   9.64311613e-10
#    2.52047367e-03   5.54135158e-18   2.87753650e-20   4.28724283e-09
#    9.09735946e-06   1.52955096e-08   1.68172602e-23   2.93204100e-01
#    0.00000000e+00]
# [ 0.20449178  0.11320927  0.08931773  0.56436982  0.2989071   0.731421
#   0.76286762  0.54579779  0.42762707  0.52902008  0.8003444   0.10614911
#   0.        ]

# %%
mainD = ['Hunger','Cost','Tortilla','Temp','Meat','Fillings','Meat:filling',
               'Uniformity','Salsa','Synergy','Wrap']

# %%
# GLM for 
import statsmodels.api as sm
X = dffull[mainD]
X = sm.add_constant(X)
y = dffull['overall']
my_glm = sm.GLM(y,X)
res = my_glm.fit()
print(res.summary())
print(res.pvalues)
print 1 - np.var(res.resid_pearson) / np.var(y)
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                overall   No. Observations:                   83
# Model:                            GLM   Df Residuals:                       71
# Model Family:                Gaussian   Df Model:                           11
# Link Function:               identity   Scale:                  0.129427348064
# Method:                          IRLS   Log-Likelihood:                -26.439
# Date:                Sun, 15 May 2016   Deviance:                       9.1893
# Time:                        10:16:41   Pearson chi2:                     9.19
# No. Iterations:                     4
# ================================================================================
#                    coef    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# const           -0.2923      0.403     -0.725      0.468        -1.082     0.498
# Hunger           0.0049      0.048      0.103      0.918        -0.089     0.098
# Cost             0.0431      0.040      1.077      0.281        -0.035     0.122
# Tortilla         0.0323      0.066      0.490      0.624        -0.097     0.162
# Temp             0.0695      0.041      1.702      0.089        -0.011     0.149
# Meat             0.1674      0.065      2.576      0.010         0.040     0.295
# Fillings         0.2167      0.071      3.058      0.002         0.078     0.356
# Meat:filling     0.0581      0.047      1.230      0.219        -0.035     0.151
# Uniformity       0.0712      0.040      1.765      0.078        -0.008     0.150
# Salsa            0.1191      0.051      2.321      0.020         0.019     0.220
# Synergy          0.2880      0.067      4.312      0.000         0.157     0.419
# Wrap            -0.0064      0.037     -0.172      0.863        -0.079     0.066
# ================================================================================
# const           0.468292
# Hunger          0.918056
# Cost            0.281437
# Tortilla        0.624405
# Temp            0.088675
# Meat            0.010001
# Fillings        0.002229
# Meat:filling    0.218752
# Uniformity      0.077546
# Salsa           0.020277
# Synergy         0.000016
# Wrap            0.863242
# dtype: float64
# 0.773676842512

# %%
# Linear regression
# Note that this matches GLM above :D
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
dffull = df[np.hstack((mainD,'overall'))].dropna()
X = dffull[mainD]
y = dffull['overall']
lm.fit(X,y)

print lm.intercept_
print lm.coef_

print 'R2 = ' + np.str(lm.score(X,y))
# Out:
# -0.292344125032
# [ 0.00491158  0.04311439  0.03231117  0.0694715   0.16736529  0.21670812
#   0.05813238  0.07120464  0.11911602  0.28796898 -0.006356  ]
# R2 = 0.773676842512

# %%
# Visualize coefficients
from tools.plt import bar
newidx = np.argsort(-res.params.values)
temp = np.arange(len(newidx))
newidx = np.delete(newidx,temp[newidx==0])
bar(res.params[newidx],res.bse[newidx],X.keys()[newidx],'Overall rating\nLinear model\ncoefficient',
    ylim =(0,.4),figsize=(11,3))
plt.plot()
# Out:
# []

# %%
sp.stats.pearsonr(X['Synergy'],y)[0]**2
# Out:
# 0.56523476092560321
