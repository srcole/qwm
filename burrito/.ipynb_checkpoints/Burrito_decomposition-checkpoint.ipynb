# %% [markdown]
# # San Diego Burrito Analytics
#
# Scott Cole
#
# 23 April 2016
#
# This notebook contains analyses on the burrito ratings in San Diego, including:
# * Machine learning

# %% [markdown]
# # Default imports

# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

import seaborn as sns
sns.set_style("white")

# %% [markdown]
# # Load data

# %%
filename="burrito_current.csv"
df = pd.read_csv(filename)
N = df.shape[0]

# %%
coreM = ['Volume','Cost','Tortilla','Temp','Meat','Fillings','Meat:filling','Uniformity','Salsa','Synergy','Wrap','overall']
df[coreM]
# Out:
#     Volume  Cost  Tortilla  Temp  Meat  Fillings  Meat:filling  Uniformity  \
# 0      NaN  6.49       3.0   5.0  3.00       3.5           4.0         4.0
# 1      NaN  5.45       2.0   3.5  2.50       2.5           2.0         4.0
# 2      NaN  4.85       3.0   2.0  2.50       3.0           4.5         4.0
# 3      NaN  5.25       3.0   2.0  3.50       3.0           4.0         5.0
# 4      NaN  6.59       4.0   5.0  4.00       3.5           4.5         5.0
# 5      NaN  6.99       3.0   4.0  5.00       3.5           2.5         2.5
# 6      NaN  7.19       2.0   3.0  3.00       2.0           2.5         2.5
# 7      NaN  6.99       2.5   3.0  3.00       2.5           3.0         3.5
# 8      NaN  9.25       2.0   4.5  4.50       3.5           1.5         3.0
# 9      NaN  6.25       2.5   1.5  1.50       3.0           4.5         3.0
# 10     NaN  9.50       2.5   2.5  2.75       2.5           2.5         2.0
# ...

# %%
# PCA on main components
from sklearn.decomposition import PCA
pca = PCA
pcaMet = ['Tortilla','Temp','Meat','Fillings','Meat:filling','Uniformity','Salsa','Synergy','Wrap']
pca.fit(df[pcaMet].as_matrix())
print pcaa.explained_variance_ratio_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-75f020c90b67> in <module>()
#       3 pca = PCA
#       4 pcaMet = ['Tortilla','Temp','Meat','Fillings','Meat:filling','Uniformity','Salsa','Synergy','Wrap']
# ----> 5 pca.fit(df[pcaMet].as_matrix())
#       6 print pcaa.explained_variance_ratio_
#
# TypeError: unbound method fit() must be called with PCA instance as first argument (got ndarray instance instead)

# %%
import numpy as np
from sklearn.decomposition import PCA
X = df[pcaMet].dropna().as_matrix()
pca = PCA()
pca.fit(X)
print(pca.explained_variance_ratio_)
# Out:
# [ 0.32307826  0.16743876  0.14566908  0.11760306  0.08239247  0.05798819
#   0.04741588  0.03256612  0.02584818]

# %%
pca.components_
# Out:
# array([[ 0.25331701,  0.23916638,  0.28761114,  0.25402883,  0.43319527,
#          0.54350039,  0.24999687,  0.37941792,  0.20462627],
#        [-0.06404172, -0.08142058, -0.26074887, -0.17793294,  0.01615906,
#         -0.07043448,  0.15728704, -0.10702316,  0.92097988],
#        [ 0.09735602,  0.91943798,  0.05987115,  0.02901801, -0.23271726,
#         -0.15490105, -0.07375318, -0.22156812,  0.08969602],
#        [-0.05057832,  0.08242425, -0.30220808, -0.35242241,  0.24675171,
#          0.61039041, -0.43823765, -0.37909506, -0.07673746],
#        [ 0.17941636, -0.10512105, -0.09602325,  0.02756898, -0.7216931 ,
#          0.4956507 ,  0.40308105, -0.12315232, -0.05125867],
#        [-0.28172802,  0.09991943,  0.172077  , -0.44711753,  0.28740676,
#         -0.04947427,  0.68051917, -0.29932508, -0.20825143],
#        [ 0.66740797,  0.02526636, -0.59936199, -0.00970797,  0.24096321,
#         -0.21585579,  0.2342961 , -0.02062141, -0.18607063],
# ...

# %%
np.shape(df[pcaMet].dropna().as_matrix())
# Out:
# (79L, 9L)
