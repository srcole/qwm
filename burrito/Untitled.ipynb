# %%
from burrito_data_sheets import main
# Out:
# usage: __main__.py [-h] [--auth_host_name AUTH_HOST_NAME]
#                    [--noauth_local_webserver]
#                    [--auth_host_port [AUTH_HOST_PORT [AUTH_HOST_PORT ...]]]
#                    [--logging_level {DEBUG,INFO,WARNING,ERROR,CRITICAL}]
# __main__.py: error: unrecognized arguments: -f C:\Users\Scott\AppData\Roaming\jupyter\runtime\kernel-f8f633e0-c0ec-4f31-9e1c-7ce8d95b306b.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\Scott\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2889: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from StringIO import StringIO  # got moved to io in python3.
import pandas as pd
import requests
r = requests.get('https://docs.google.com/spreadsheet/ccc?key=18HkrklYz1bKpDLeL-kaMrGjAhUM6LeJMIACwEljCgaw&output=csv')
data = r.content
df = pd.read_csv(StringIO(data))
# Out:
#                Location      Burrito       Date Neighborhood  \
# 0    Donato's taco shop  California   1/18/2016      Miramar
# 1  Oscar's Mexican food  California   1/24/2016   San Marcos
# 2  Oscar's Mexican food     Carnitas  1/24/2016          NaN
# 3  Oscar's Mexican food  Carne asada  1/24/2016          NaN
# 4          Pollos Maria   California  1/27/2016     Carlsbad
#
#                     Address  \
# 0           6780 Miramar Rd
# 1  225 S Rancho Santa Fe Rd
# 2                       NaN
# 3                       NaN
# 4           3055 Harding St
#
#                                                  URL  Yelp  Google Chips  \
# 0                        http://donatostacoshop.net/   3.5     4.2   NaN
# 1  http://www.yelp.com/biz/oscars-mexican-food-sa...   3.5     3.3   NaN
# 2                                                NaN   NaN     NaN   NaN
# 3                                                NaN   NaN     NaN   NaN
# 4                            http://pollosmaria.com/   4.0     3.8     x
#
#    Cost    ...     Nopales  Lobster  Queso  Egg  Mushroom  Bacon  Sushi  \
# 0  6.49    ...         NaN      NaN    NaN  NaN       NaN    NaN    NaN
# 1  5.45    ...         NaN      NaN    NaN  NaN       NaN    NaN    NaN
# 2  4.85    ...         NaN      NaN    NaN  NaN       NaN    NaN    NaN
# 3  5.25    ...         NaN      NaN    NaN  NaN       NaN    NaN    NaN
# 4  6.59    ...         NaN      NaN    NaN  NaN       NaN    NaN    NaN
#
#    Avocado  Corn  Zucchini
# 0      NaN   NaN       NaN
# 1      NaN   NaN       NaN
# 2      NaN   NaN       NaN
# 3      NaN   NaN       NaN
# 4      NaN   NaN       NaN
#
# [5 rows x 64 columns]
